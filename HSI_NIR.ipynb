# %% [markdown]
# <a href="https://colab.research.google.com/github/kb-open/hsi_nir/blob/main/HSI_NIR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
sns.axes_style('whitegrid');

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.decomposition import PCA

# %%
# !wget http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat http://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
# Out:
# --2022-08-30 06:50:40--  http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat [following]
# --2022-08-30 06:50:40--  https://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5953527 (5.7M)
# Saving to: ‘Indian_pines_corrected.mat’
#
# Indian_pines_correc 100%[===================>]   5.68M   369KB/s    in 12s
#
# 2022-08-30 06:50:53 (482 KB/s) - ‘Indian_pines_corrected.mat’ saved [5953527/5953527]
#
# --2022-08-30 06:50:53--  http://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat [following]
# --2022-08-30 06:50:53--  https://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1125 (1.1K)
# Saving to: ‘Indian_pines_gt.mat’
#
# Indian_pines_gt.mat 100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2022-08-30 06:50:54 (48.1 MB/s) - ‘Indian_pines_gt.mat’ saved [1125/1125]
#
# FINISHED --2022-08-30 06:50:54--
# Total wall clock time: 14s
# Downloaded: 2 files, 5.7M in 12s (482 KB/s)

# %%
# !ls
# Out:
# Indian_pines_corrected.mat  Indian_pines_gt.mat  sample_data

# %%
def read_HSI():
  X = loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']
  y = loadmat('Indian_pines_gt.mat')['indian_pines_gt']
  print(f"X shape: {X.shape}\ny shape: {y.shape}")
  return X, y

# %%
def extract_pixels(X, y):
  q = X.reshape(-1, X.shape[2])
  df = pd.DataFrame(data = q)
  df = pd.concat([df, pd.DataFrame(data = y.ravel())], axis=1)
  df.columns= [f'band{i}' for i in range(1, 1+X.shape[2])]+['class']
  df.to_csv('Dataset.csv')
  return df

# %%
X, y = read_HSI()
# Out:
# X shape: (145, 145, 200)
# y shape: (145, 145)

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Bands

# %%
fig = plt.figure(figsize = (12, 6))

for i in range(1, 1+6):
    fig.add_subplot(2,3, i)
    q = np.random.randint(X.shape[2])
    plt.imshow(X[:,:,q], cmap='nipy_spectral')
    plt.axis('off')
    plt.title(f'Band - {q}')
plt.savefig('IP_Bands.png')

# %% [markdown]
# ## Ground Truth

# %%
plt.figure(figsize=(10, 8))
plt.imshow(y, cmap='nipy_spectral')
plt.colorbar()
plt.axis('off')
plt.savefig('IP_GT.png')
plt.show()

# %% [markdown]
# # Preprocess

# %%
df = extract_pixels(X, y)
df.head()
# Out:
#    band1  band2  band3  band4  band5  band6  band7  band8  band9  band10  ...  \
# 0   3172   4142   4506   4279   4782   5048   5213   5106   5053    4750  ...
# 1   2580   4266   4502   4426   4853   5249   5352   5353   5347    5065  ...
# 2   3687   4266   4421   4498   5019   5293   5438   5427   5383    5132  ...
# 3   2749   4258   4603   4493   4958   5234   5417   5355   5349    5096  ...
# 4   2746   4018   4675   4417   4886   5117   5215   5096   5098    4834  ...
#
#    band192  band193  band194  band195  band196  band197  band198  band199  \
# 0     1094     1090     1112     1090     1062     1069     1057     1020
# 1     1108     1104     1117     1091     1079     1085     1064     1029
# 2     1111     1114     1114     1100     1065     1092     1061     1030
# 3     1122     1108     1109     1109     1071     1088     1060     1030
# 4     1110     1107     1112     1094     1072     1087     1052     1034
#
#    band200  class
# 0     1020      3
# 1     1020      3
# 2     1016      3
# 3     1006      3
# 4     1019      3
#
# [5 rows x 201 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21025 entries, 0 to 21024
# Columns: 201 entries, band1 to class
# dtypes: uint16(200), uint8(1)
# memory usage: 8.0 MB

# %%
df.iloc[:, :-1].describe()
# Out:
#               band1         band2         band3         band4         band5  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    2957.363472   4091.321237   4277.502259   4169.956671   4516.678668
# std      354.918708    230.390005    257.827640    280.761254    346.035984
# min     2560.000000   2709.000000   3649.000000   2810.000000   3840.000000
# 25%     2602.000000   3889.000000   4066.000000   3954.000000   4214.000000
# 50%     2780.000000   4106.000000   4237.000000   4126.000000   4478.000000
# 75%     3179.000000   4247.000000   4479.000000   4350.000000   4772.000000
# max     4536.000000   5744.000000   6361.000000   6362.000000   7153.000000
#
#               band6         band7         band8         band9        band10  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    4790.595149   4848.317574   4714.732509   4668.904828   4439.065541
# std      414.382138    469.247667    491.728349    533.232855    539.908195
# min     4056.000000   4004.000000   3865.000000   3775.000000   2792.000000
# 25%     4425.000000   4421.000000   4263.000000   4173.000000   3940.000000
# 50%     4754.000000   4808.000000   4666.000000   4632.000000   4404.000000
# 75%     5093.000000   5198.000000   5100.000000   5084.000000   4860.000000
# max     7980.000000   8284.000000   8128.000000   8194.000000   7928.000000
#
#        ...       band191       band192       band193       band194  \
# count  ...  21025.000000  21025.000000  21025.000000  21025.000000
# mean   ...   1079.310773   1061.927848   1060.210273   1063.276813
# std    ...     49.943791     38.843805     38.712195     41.920969
# min    ...    998.000000    998.000000    999.000000    999.000000
# 25%    ...   1031.000000   1026.000000   1024.000000   1024.000000
# 50%    ...   1068.000000   1053.000000   1052.000000   1054.000000
# 75%    ...   1129.000000   1099.000000   1098.000000   1104.000000
# max    ...   1364.000000   1287.000000   1289.000000   1315.000000
#
#             band195       band196       band197       band198       band199  \
# count  21025.000000  21025.000000  21025.000000  21025.000000  21025.000000
# mean    1050.048514   1040.201141   1043.370321   1030.194816   1015.571463
# std       34.242725     26.452672     29.794418     20.865106     11.386402
# min      993.000000    990.000000    992.000000    989.000000    986.000000
# 25%     1019.000000   1016.000000   1016.000000   1012.000000   1006.000000
# 50%     1043.000000   1033.000000   1035.000000   1026.000000   1014.000000
# 75%     1083.000000   1066.000000   1072.000000   1050.000000   1024.000000
# max     1258.000000   1201.000000   1245.000000   1167.000000   1076.000000
#
#             band200
# count  21025.000000
# mean    1008.513579
# std        7.050921
# min      981.000000
# 25%     1004.000000
# 50%     1009.000000
# 75%     1014.000000
# max     1036.000000
#
# [8 rows x 200 columns]

# %% [markdown]
# ## PCA

# %%
pca = PCA(n_components = 100)

principalComponents = pca.fit_transform(df.iloc[:, :-1].values)

ev=pca.explained_variance_ratio_

plt.figure(figsize=(12, 6))
plt.plot(np.cumsum(ev))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')

plt.show()

# %%
pca = PCA(n_components = 40)
dt = pca.fit_transform(df.iloc[:, :-1].values)
q = pd.concat([pd.DataFrame(data = dt), pd.DataFrame(data = y.ravel())], axis = 1)
q.columns = [f'PC-{i}' for i in range(1,41)]+['class']

q.head()
# Out:
#           PC-1         PC-2        PC-3        PC-4        PC-5        PC-6  \
# 0  5014.905985  1456.863260   72.697049   71.204930 -435.686983  -68.840315
# 1  5601.383743 -2023.450087  350.134661 -528.465048  148.088294 -288.359021
# 2  5796.135442 -3090.394852  490.539929 -760.214348  259.933300 -131.611174
# 3  5586.204575 -2369.376085  356.274719 -502.687152  146.554955 -306.679329
# 4  5020.990792   339.603390  -23.007525  -92.556768 -368.495435 -438.266715
#
#          PC-7        PC-8        PC-9       PC-10  ...       PC-32      PC-33  \
# 0  134.809922 -304.372538  256.432866  -66.631045  ...   20.012370  -6.339948
# 1  202.956935  240.848035 -474.857990   93.493841  ...  100.807786 -83.427411
# 2  172.927292  205.911123  572.492037 -191.622276  ...   33.878570 -37.601219
# 3  251.071147  234.966524 -314.023423   54.962215  ...  129.831024 -66.092785
# 4  502.715422 -345.536518 -188.352803  -67.506002  ...  -81.671712  74.643896
#
#         PC-34      PC-35      PC-36      PC-37      PC-38      PC-39  \
# 0   20.391660 -19.578032 -31.302161  17.836143   0.844043  61.637863
# 1  -51.015365  29.164366  12.842639 -28.322293  -0.474057  13.107404
# 2  -16.642535  21.081325  35.764951 -15.973960 -23.909154 -33.324923
# 3   34.477866  20.733331  66.313497 -15.729797 -47.889538   0.214135
# 4  183.988021  -9.739793 -13.220084 -15.399027   4.294916  59.329444
#
#        PC-40  class
# 0   3.071549      3
# 1  35.653971      3
# 2  85.632604      3
# 3  55.594421      3
# 4  18.781599      3
#
# [5 rows x 41 columns]

# %%
fig = plt.figure(figsize = (20, 10))

for i in range(1, 1+8):
    fig.add_subplot(2,4, i)
    plt.imshow(q.loc[:, f'PC-{i}'].values.reshape(145, 145), cmap='nipy_spectral')
    plt.axis('off')
    plt.title(f'Band - {i}')

plt.savefig('IP_PCA_Bands.png')

# %%
q.to_csv('IP_40_PCA.csv', index=False)

# %% [markdown]
# # Model

# %% [markdown]
# ## SVC

# %%
x = q[q['class'] != 0]

X = x.iloc[:, :-1].values

y = x.loc[:, 'class'].values 

names = ['Alfalfa',	'Corn-notill', 'Corn-mintill',	'Corn',		'Grass-pasture','Grass-trees',
'Grass-pasture-mowed','Hay-windrowed','Oats','Soybean-notill','Soybean-mintill',
'Soybean-clean', 'Wheat',	'Woods',	'Buildings Grass Trees Drives',	'Stone Steel Towers']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=11, stratify=y)

model =  SVC(C = 100, kernel = 'rbf', cache_size = 10*1024)

model.fit(X_train, y_train)
# Out:
# SVC(C=100, cache_size=10240)

# %%
ypred = model.predict(X_test)

# %%
data = confusion_matrix(y_test, ypred)
df_cm = pd.DataFrame(data, columns=np.unique(names), index = np.unique(names))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,8))
sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, cmap="Reds", annot=True,annot_kws={"size": 16}, fmt='d')
plt.savefig('cmap.png', dpi=300)

# %%
print(classification_report(y_test, ypred, target_names = names))
# Out:
#                               precision    recall  f1-score   support
#
#                      Alfalfa       1.00      0.89      0.94         9
#                  Corn-notill       0.82      0.81      0.81       286
#                 Corn-mintill       0.89      0.80      0.84       166
#                         Corn       0.79      0.79      0.79        47
#                Grass-pasture       0.92      0.96      0.94        97
#                  Grass-trees       0.97      0.97      0.97       146
#          Grass-pasture-mowed       1.00      0.80      0.89         5
#                Hay-windrowed       0.99      1.00      0.99        96
#                         Oats       0.60      0.75      0.67         4
#               Soybean-notill       0.87      0.80      0.83       194
#              Soybean-mintill       0.85      0.91      0.88       491
#                Soybean-clean       0.85      0.88      0.86       119
#                        Wheat       0.95      1.00      0.98        41
#                        Woods       0.96      0.98      0.97       253
# Buildings Grass Trees Drives       0.92      0.73      0.81        77
#           Stone Steel Towers       1.00      1.00      1.00        19
#
#                     accuracy                           0.89      2050
#                    macro avg       0.90      0.88      0.89      2050
#                 weighted avg       0.89      0.89      0.89      2050

# %%
l=[]
for i in range(q.shape[0]):
  if q.iloc[i, -1] == 0:
    l.append(0)
  else:
    l.append(model.predict(q.iloc[i, :-1].values.reshape(1, -1)))

clmap = np.array(l).reshape(145, 145).astype('float')
plt.figure(figsize=(10, 8))
plt.imshow(clmap, cmap='nipy_spectral')
plt.colorbar()
plt.axis('off')
plt.savefig('IP_cmap.png')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
